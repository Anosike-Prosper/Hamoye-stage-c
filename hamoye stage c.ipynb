# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import recall_score, accuracy_score, precision_score, f1_score, confusion_matrix

# %%
data= pd.read_csv('Data_for_UCI_named (1).csv')

data
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
# ...

# %%
data.isnull().sum()
# Out:
# tau1     0
# tau2     0
# tau3     0
# tau4     0
# p1       0
# p2       0
# p3       0
# p4       0
# g1       0
# g2       0
# g3       0
# g4       0
# stab     0
# stabf    0
# dtype: int64

# %%
data.drop('stab', axis=1, inplace=True)

data
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4     stabf
# ...

# %%
data.stabf.value_counts()
# Out:
# unstable    6380
# stable      3620
# Name: stabf, dtype: int64

# %%
x = data.drop('stabf', axis= 1)

y= data['stabf']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size= 0.2 , random_state= 1 ) # splitting the data

# %%
y_train.value_counts()
# Out:
# unstable    5092
# stable      2908
# Name: stabf, dtype: int64

# %%
y_test.value_counts()
# Out:
# unstable    1288
# stable       712
# Name: stabf, dtype: int64

# %%
X_train.head()
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 2694  6.255995  2.542401  7.024714  9.476518  3.529888 -1.224881 -0.688228
# 5140  5.070581  5.490253  8.075688  0.761075  4.220888 -1.280596 -1.902185
# 2568  1.220072  8.804028  3.874283  8.433949  3.614027 -1.039236 -0.953566
# 3671  7.498402  6.697603  8.798626  2.126236  3.134585 -1.581906 -0.589386
# 7427  7.074006  1.337511  6.100756  7.759156  2.526922 -0.922540 -0.632600
#
#             p4        g1        g2        g3        g4
# 2694 -1.616780  0.568221  0.618403  0.685739  0.660088
# 5140 -1.038107  0.443515  0.097244  0.916955  0.129254
# 2568 -1.621224  0.908353  0.923594  0.238881  0.660156
# 3671 -0.963293  0.260826  0.899003  0.964752  0.600598
# 7427 -0.971782  0.984580  0.716082  0.836928  0.165162

# %%
X_test.head()
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 9953  6.877876  4.113820  9.356768  8.299753  4.056779 -1.897470 -1.590581
# 3850  5.802841  6.271371  4.731540  3.819867  3.579569 -1.709480 -1.067511
# 4962  2.286998  4.385142  2.830232  5.293880  3.035814 -1.202764 -0.902011
# 3886  5.019920  2.209962  6.266080  0.578901  4.322584 -1.960207 -1.074561
# 5437  7.646145  9.187896  5.484219  9.934313  3.634226 -1.254541 -1.335366
#
#             p4        g1        g2        g3        g4
# 9953 -0.568728  0.276567  0.845536  0.112440  0.822562
# 3850 -0.802579  0.077527  0.416478  0.912846  0.861306
# 4962 -0.931039  0.924216  0.130186  0.703887  0.063811
# 3886 -1.287815  0.546910  0.065992  0.427349  0.814648
# 5437 -1.044319  0.561528  0.121611  0.787318  0.300314

# %%
scaler = StandardScaler() # using the standard scaler

# %%
normalised_train_df = scaler.fit_transform(X_train) 
normalised_train_df = pd.DataFrame(normalised_train_df, columns=X_train.columns )

normalised_train_df.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  0.367327 -0.986042  0.650447  1.547527 -0.291490  0.061535  1.293862
# 1 -0.064659  0.089437  1.035079 -1.641494  0.619865 -0.067235 -1.502925
# 2 -1.467850  1.298418 -0.502536  1.166046 -0.180521  0.490603  0.682560
# 3  0.820081  0.529920  1.299657 -1.141975 -0.812854 -0.763632  1.521579
# 4  0.665424 -1.425627  0.312300  0.919137 -1.614296  0.760315  1.422019
#
#          p4        g1        g2        g3        g4
# 0 -0.845074  0.160918  0.339859  0.585568  0.492239
# 1  0.486613 -0.293143 -1.558488  1.429649 -1.443521
# 2 -0.855302  1.399350  1.451534 -1.045743  0.492489
# 3  0.658780 -0.958319  1.361958  1.604140  0.275303
# 4  0.639243  1.676895  0.695660  1.137504 -1.312575

# %%
X_test= X_test.reset_index(drop= True)

normalised_test_df = scaler.transform(X_test) 
normalised_test_df = pd.DataFrame(normalised_test_df, columns=X_train.columns )

normalised_test_df.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  0.593951 -0.412733  1.503924  1.116943  0.403423 -1.492971 -0.785033
# 1  0.202190  0.374416 -0.188800 -0.522268 -0.225967 -1.058483  0.420047
# 2 -1.079044 -0.313745 -0.884634  0.017080 -0.943122  0.112653  0.801335
# 3 -0.083120 -1.107327  0.372805 -1.708152  0.753990 -1.637972  0.403805
# 4  0.873921  1.438466  0.086662  1.715037 -0.153880 -0.007015 -0.197053
#
#          p4        g1        g2        g3        g4
# 0  1.566781 -0.901007  1.167203 -1.507330  1.084726
# 1  1.028627 -1.625721 -0.395660  1.414651  1.226011
# 2  0.733004  1.457108 -1.438495  0.651821 -1.682168
# 3 -0.088036  0.083322 -1.672322 -0.357714  1.055865
# 4  0.472315  0.136549 -1.469731  0.956396 -0.819727

# %%
# random forest classifier

from sklearn.ensemble import RandomForestClassifier


Random_forest = RandomForestClassifier(random_state=1)
Random_forest.fit(normalised_train_df, y_train)

prediction = Random_forest.predict(normalised_test_df)

# %%
print('Accuracy score is', accuracy_score(y_test, prediction)) 
print('Precision score for label stable is' ,  precision_score(y_test, prediction, pos_label='stable'))
print('Recall score for label stable is', recall_score(y_test, prediction, pos_label='stable'))
print('F1 score is',  f1_score(y_test, prediction, pos_label='stable'))
# Out:
# Accuracy score is 0.929
# Precision score for label stable is 0.9191176470588235
# Recall score for label stable is 0.8778089887640449
# F1 score is 0.8979885057471264

# %%
from xgboost import XGBClassifier

xgb_class = XGBClassifier(random_state =1, max_depth=3, learning_rate= 0.1)
xgb_class.fit(normalised_train_df, y_train)


xgb_pred = xgb_class.predict(normalised_test_df)
# Out:
# C:\Users\ProsK\anaconda3\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [12:11:30] WARNING: ..\src\learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
round(accuracy_score(y_true=y_test, y_pred=xgb_pred), 4)
# Out:
# 0.9195

# %%
# for this, my answer was not in the option, so i chose the closest answer

from lightgbm import LGBMClassifier


lgbm_class = LGBMClassifier(random_state=1)
lgbm_class.fit(normalised_train_df, y_train)
lgbm_predict  = lgbm_class.predict(normalised_test_df)

round(accuracy_score(y_test, lgbm_predict) , 4)
# Out:
# 0.9395

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import RandomizedSearchCV

Ext_tree = ExtraTreesClassifier (random_state = 1)

# %%
n_estimators = [50, 100, 300, 500, 1000]    # Given we are to use this parameters to answer the question

min_samples_split = [2, 3, 5, 7, 9]

min_samples_leaf = [1, 2, 4, 6, 8]

max_features = ['auto', 'sqrt', 'log2', None] 

hyperparameter_grid = {'n_estimators': n_estimators,

                       'min_samples_leaf': min_samples_leaf,

                       'min_samples_split': min_samples_split,

                       'max_features': max_features}

# %%
Random_search = RandomizedSearchCV(estimator = Ext_tree, param_distributions= hyperparameter_grid, random_state=1,cv = 5, n_iter=10,scoring='accuracy',n_jobs=1, verbose=1)

# %%
hyp_params = Random_search.fit(normalised_train_df, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
hyp_params.best_params_ # these are the best hyperparameters for the model
# Out:
# {'n_estimators': 1000,
#  'min_samples_split': 2,
#  'min_samples_leaf': 8,
#  'max_features': None}

# %%
# new model using hyper parameters above

New_ext_tree = ExtraTreesClassifier(n_estimators=1000, min_samples_split=2, 
                                 min_samples_leaf=8, max_features=None)
New_ext_tree.fit(normalised_train_df, y_train)
Ext_pred = New_ext_tree.predict(normalised_test_df)

# %%
accuracy_score(y_test, Ext_pred)
# Out:
# 0.927

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, Ext_pred))
# Out:
#               precision    recall  f1-score   support
#
#       stable       0.92      0.87      0.89       712
#     unstable       0.93      0.96      0.94      1288
#
#     accuracy                           0.93      2000
#    macro avg       0.93      0.91      0.92      2000
# weighted avg       0.93      0.93      0.93      2000

# %%
# comparing the results


Ext_tree.fit(normalised_train_df, y_train) # old model without hyper parameter. the accuracy of the old model is higher
Tree_predict = Ext_tree.predict(normalised_test_df)

# print( classification_report (y_test,Tree_predict) )

accuracy_score(y_test, Tree_predict)
# Out:
# 0.928

# %%
important_feat = hyp_params.best_estimator_.feature_importances_
print ( important_feat)  # this code helps us to generate the importance features
# Out:
# [0.13723975 0.1405075  0.13468029 0.13541676 0.00368342 0.00533686
#  0.00542927 0.00496249 0.10256244 0.10757765 0.11306268 0.10954089]

# %%
sorted (zip(important_feat, x), reverse = True)  # this code maps each feature to its respective names
# Out:
# [(0.14050750384993677, 'tau2'),
#  (0.13723974766109256, 'tau1'),
#  (0.1354167630909727, 'tau4'),
#  (0.13468028520386593, 'tau3'),
#  (0.11306267999167334, 'g3'),
#  (0.10954089174337298, 'g4'),
#  (0.10757764577478764, 'g2'),
#  (0.10256244080927947, 'g1'),
#  (0.005429268421191957, 'p3'),
#  (0.005336864710946151, 'p2'),
#  (0.004962486591192238, 'p4'),
#  (0.003683422151688322, 'p1')]

# %%
precision= (355/(355+1480)) # compution precision and recall for question 1
recall= (355/(355+45))

# %%
2 * ((precision*recall)/(precision+recall)) # the f1 score
# Out:
# 0.3176733780760626
